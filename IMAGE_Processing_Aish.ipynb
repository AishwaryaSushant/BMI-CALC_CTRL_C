# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwaryaSushant/BMI-CALC_CTRL_C/blob/main/IMAGE_Processing_Aish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot  as plt
from skimage import data
from skimage.util import img_as_ubyte
from skimage import io

import matplotlib.pyplot as plt
path="/content/sample_data/baboon.jpg"

image= plt.imread(path)
plt.imshow(image)

# %%
plt.imsave(path + " Aishwarya " + '.jpg', image)

# %%
print(image.shape)
# Out:
# (225, 225, 3)

# %%
from skimage.color import rgb2gray
gray_img=rgb2gray(image)
plt.imshow(gray_img,cmap = 'gray')

# %%
import numpy as np
v_flip=np.flip(gray_img,axis=1)
plt.imshow(v_flip,cmap= 'gray')

# %%
h_flip=np.flip(gray_img,axis=0)
plt.imshow(h_flip,cmap = 'gray')

# %%
from scipy import ndimage
img = data.camera()
rot_img = ndimage.rotate(img, 60,reshape=False)
plt.imshow(rot_img, cmap='gray')
